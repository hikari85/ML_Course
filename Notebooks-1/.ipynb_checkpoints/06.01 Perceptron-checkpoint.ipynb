# %% [markdown]
# #### Neural Network Representation
# - Loosely inspired by biological neurons
#       Neurons take input from other neurons, apply transformation & pass signal on
#
# - NNs have become very successful in recent years
# - Are often among the best algorithms in top ML competitions (especially with images, audio, video, etc.)
# ##### Why?
# - Lots of parameters = ability to build very complex models
# - Recent advances in computation (GPUs) and algorithms (backpropagation) has allowedfor more layers (more complex models)
# - NNs are hard to understand and interpret
# - We know inputs and outputs, but the middle layers are merely numbers from our point of view
# - Lots of work is being done to “open up” black box models so we can understand what they are doing

# %% [markdown]
# ##### Feedforward Neural Networks (FNN)
# The simplest type. One-way street for data — information travels straight from the input, through any hidden layers, and out the other side to the output. For simple predictions and sorting things into categories.
#
# ##### Convolutional Neural Networks (CNN)
# Mainly for computer vision.
#
# ##### Recurrent Neural Networks (RNN)
# RNNs have a memory of sorts, making them great for anything involving sequences of data, like sentences, DNA sequences, handwriting, or stock market trends. They loop information back around, allowing them to remember previous inputs in the sequence. This makes them ace at tasks like predicting the next word in a sentence or understanding spoken language.
#
# ##### Long Short-Term Memory Networks (LSTM)
# LSTMs are a special breed of RNNs built to remember things for longer stretches. They’re designed to solve the problem of RNNs forgetting stuff over long sequences. If you’re dealing with complex tasks that need to hold onto information for a long time, like translating paragraphs or predicting what happens next in a TV series.
#
# ##### Generative Adversarial Networks (GAN)
# Imagine two AIs in a cat-and-mouse game: one generates fake data (like images), and the other tries to catch what’s fake and what’s real. That’s a GAN. This setup allows GANs to create incredibly realistic images, music, text, and more. They’re the artists of the neural network world, generating new, realistic data from scratch.

# %%
from IPython.display import Image

# %% [markdown]
# #### Perceptron
# 1958, Frank Rosenblatt.
# <center><img src="../Figures/perceptron.PNG" width="800" height="200"></center>
#
# The function may be re-written as
# $$f(w_0 + w_1\cdot x_1 + w_2 \cdot x_2 + ... + w_n \cdot x_n)$$

# %%
Image('../Figures/perceptron_flow.PNG')

# %%
Image('../Figures/perceptron_model.png')

# %% [markdown]
# #### Perceptron
# ##### Definition
# The perceptron is the simplest form of a neural network, introduced by Frank Rosenblatt in 1957.
# It is a **binary classifier** that takes multiple binary inputs and produces a single binary output.
# ##### Architecture
# The perceptron consists of
# - input nodes, each associated with a weight,
# - a summation function,
# - an activation function, and
# - a single output node.
# The weights represent the strengths of the connections between the input nodes and the output.
# ##### Operation
# The output of the perceptron is determined by
# - applying the weights to the input values,
# - computing their sum, and
# - passing the result through an activation function (typically a step function).
# The output is binary, indicating the predicted class.
# ##### Learning
# The perceptron learns by adjusting its weights based on the error in its predictions.
# Rosenblatt’s perceptron rule updates the weights to reduce the error,
# moving the decision boundary in the input space.

# %% [markdown]
# #### What is the Perceptron Model?
# It is a binary linear classification algorithm. It is the simplest forms of a neural network, making decisions based on a linear combination of its inputs.
# - Inputs: Each input is assigned a weight, signifying its importance. These weighted inputs are then summed.
# - Weights: These parameters are crucial in determining the influence of each input. They are adjusted during the learning process.
# - Summation Function: The weighted inputs are summed together, forming a linear combination.
# - Activation Function: The result of the summation is then passed through an activation function, often a step function, to yield the final output.
#
# #### Learning in the Perceptron Model
# Learning in the perceptron model is a process of adjusting the weights to make accurate predictions.
# 1. Initialization of Weights: The process begins with assigning random weights to the inputs.
# Output Calculation: Inputs are multiplied by their respective weights, summed, and passed through the activation function to produce an output.
# 3. Output Comparison: The predicted output is compared with the actual output.
# 4. Weight Adjustment: In the event of misclassification, weights are adjusted accordingly.
# 5. Iteration: Steps 2–4 are repeated until the perceptron accurately classifies the inputs.
#
# #### Limitations and Evolution
# While the perceptron model is a powerful concept, **it can only handle linearly separable data**. It struggles with problems that need non-linear decision boundaries.
# Sophisticated neural networks, such as multi-layer perceptrons (MLPs), can tackle complex tasks.

# %% [markdown]
# **Step Function**: 1 if > 0 else 0
# **Summation Process**:   $x_1.w_1 + x_2.w_2 ... x_i.w_i$

# %% [markdown]
# ##### Math of NN
# Weighted sum $z = \sum w_ix_i + b$
#
# Activation Function sigmoid $f(x) = \frac {1}{1+e^{-x}} $
#
# softmax
#
# $f(x) = tanh(x) = \frac {2}{1+e^{-2x}} - 1$
#
# Rectified Linear Unit $f(x) = max(0, x)$
#
# Gradient descent $w_{new} = w_{old}\ -\ lr\ .\ \frac {\delta L}{\delta w}$
#
# Leaky reLU $f(x) = max(\alpha x, x)$
#
# Exponential ReLU

# %% [markdown]
# ##### Keras
# Keras is the high-level API of the TensorFlow platform.
# In Colab tensorflow is pre-installed, not in Anaconda.
# [tensorflow](https://developers.google.com/machine-learning/crash-course/first-steps-with-tensorflow/toolkit#:~:text=TensorFlow%20is%20an%20end%2Dto,and%20train%20machine%20learning%20models.)

# %% [raw]
# !pip install TensorFlow

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from random import randint

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### One neuron network

# %%
model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

X = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
y = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0], dtype=float)

model.fit(X, y, epochs=500) 

model.save('../Data/one_neuron.h5')

# %% [markdown]
# Before training (`model.fit`), the computer does not know the relationship between X and Y.
#  It makes a guess (say, y = 10X + 10). Then, with loss function it measures how good or how bad that guess is. The loss function compares the value in the $y$ of training set and the result of guessed function.
#
# The optimiser makes another guess based on the result of loss function. In this case we picked sgd (stochastic gradient descent) optimiser. Its job is to minimize the loss, and bring the guessed formula closer and closer to the correct answer.
#
#  epochs=500 means “fit the Xs to the Ys, and try it 500 times.” The optimiser will guess a function to reduce the loss in each epoch.

# %% [markdown]
# Read the saved model
# Test the model
# The function can be seen as $y = 2X -1$

# %%
from keras.models import load_model
model = load_model('../Data/one_neuron.h5')
for num in range(5, 12, 2):   # 5, 7, 9, and 11 as input values
    print(f"{num = :2}  predicted = {model.predict([num])[0,0]:.2f}\n")
# Out:
# 1/1 [==============================] - 0s 168ms/step
# num =  5  predicted = 8.99
#
# 1/1 [==============================] - 0s 69ms/step
# num =  7  predicted = 12.99
#
# 1/1 [==============================] - 0s 82ms/step
# num =  9  predicted = 16.98
#
# 1/1 [==============================] - 0s 89ms/step
# num = 11  predicted = 20.98

# %%
num = randint(1, 100)

print(f"\n{num = :2}  predicted = {model.predict([num])[0,0]:.2f}\n")
# Out:
# 1/1 [==============================] - 0s 76ms/step
#
# num = 98  predicted = 194.74

# %% [markdown]
# #### Task
# In the example abovbe, reduce the number of epochs and test the result.

# %% [markdown]
# #### Check Weights

# %%
print(f"\nprediction for value of 10: {model.predict([10.0])}")
print(f"\nWeights learned by network: {model.get_weights()}")
# Out:
# 1/1 [==============================] - 0s 84ms/step
#
# prediction for value of 10: [[18.980764]]
#
# Weights learned by network: [array([[1.997212]], dtype=float32), array([-0.99135643], dtype=float32)]

# %%
rule = model.get_weights()

print(rule)
print(f"Weight: {rule[0][0,0]}\nBias:  {rule[1][0]}\nwhich is close to 2x-1")
# Out:
# [array([[1.997212]], dtype=float32), array([-0.99135643], dtype=float32)]
# Weight: 1.9972120523452759
# Bias:  -0.9913564324378967
# which is close to 2x-1
