# %% [markdown]
# https://www.analyticsvidhya.com/blog/2018/08/dimensionality-reduction-techniques-python/#h2_3
# ### Common Dimensionality Reduction Techniques
# 1. Missing Value Ratio
# 2. Low Variance Filter
# 3. High Correlation Filter
# 4. Random Forest
# 5. Backward Feature Elimination
# 6. Forward Feature Selection
# 7. Factor Analysis
# 8. Principal Component Analysis
# 9. Independent Component Analysis
# 10. Methods Based on Projections
# 11. t-Distributed Stochastic Neighbor Embedding (t-SNE)
# 12. UMAP

# %%
import pandas as pd

# %%
df = pd.read_excel('../Data/DS_Student_Data.xlsx').head()
# df.columns
df.set_index('Student_ID').plot.bar();
# Out:
# <AxesSubplot:xlabel='Student_ID'>

# %%
df['wt_lb'] = df.Weight*2.2
df['ht_in'] = df.Height/2.54

# %%
df.set_index('Student_ID').plot.bar();
