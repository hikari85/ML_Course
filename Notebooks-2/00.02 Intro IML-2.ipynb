# %% [markdown]
# ##### Discovery
# Kishor, Phalguni, Prasanna, and Puneeth have discovered that
# - your teachers are useless and
# - the students are extra ordinary.
# - attending classes does not add value
#     because you CGPA has no correlation with attendance.
#
# ##### School Policy
# Minimum attendance = 80%
# <u>Note</u>: A students with 76% attendance and another with 71% were NE for DBMS-1 test in B.Sc.23
# Late comers will be marked so, leading to loss of attendance
#
# **It is your time to approach the management and get the policies corrected**

# %% [markdown]
# #### Syllabus for IML-2
# 1. Multiple Linear Regression
# 2. Grid Search, Hyperparameter Tuning
# 3. Model evaluation using cross-validation, confusion matrix, classification report and area under curve for Decision Tree
# 4. Principal Component Analysis
# 5. Convolutional Neural Network - CNN
# 6. Project
#
# ##### Overfolow from IML-1
# Perceptron, Logistic regression, sigmoid activation function, binary classification, error back propagation algorithm, feed-forward neural network, Universal Approximation Theorem

# %% [raw]
# Last teaching day: 03 May
# Prep leave         04  to 14 May
# CIE                06 to 09 May
# SEE                15 TO 29 May
# Next sem starts    01 Aug

# %% [raw]
# Classes on 18 days = 27 hours in 6 weeks
# Self study periods =  6 hours
# Eval of class work - regular
#         class work will include short written tests
#         and the work done on self-study periods
#
# One assignment per week
# Written test 06 - 09 May
# Final project submission by 13 May
# Viva 15 - 19 May
