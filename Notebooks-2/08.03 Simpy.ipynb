# %% [markdown]
# #### Simulation Py Plotting
# https://gaurav-adarshi.medium.com/introduction-to-simpy-simulation-py-04-b08867665442
# Plotting support is defined in sympy.plotting module.
# - plot − 2D line plots
# - plot3d − 3D line plots
# - plot_parametric − 2D parametric plots
# - plot3d_parametric − 3D parametric plots
#
# plot(expr, range, kwargs)
# default range is (-10, 10)
#
# optional keyword arguments in plot() function.
# - line_color − specifies color of the plot line.
# - title − a string to be displayed as title
# - xlabel − a string to be displayed as label for X axis
# - ylabel − a string to be displayed as label for y axis

# %% [raw]
# ! pip install simpy

# %%
from sympy.plotting import plot
from sympy import *

# %%
x = Symbol('x')
plot(x**2, line_color='red');

# %% [markdown]
# ##### Multiple plots

# %%
plot( sin(x), cos(x), (x, -pi, pi));

# %%
plot( (sin(x),(x, -2*pi, 2*pi)),(cos(x), (x, -pi, pi)));

# %% [markdown]
# #### The plot3d()
# plot3d(expr, xrange, yrange, kwargs)

# %%
from sympy.plotting import plot3d 
x,y = symbols('x y') 
plot3d(x*y, (x, -10,10), (y, -10,10));

# %%
plot3d(x*y, x/y, (x, -5, 5), (y, -5, 5));

# %% [markdown]
# ####  plot3d_parametric_line()
# renders a 3 dimensional parametric line plot.

# %%
from sympy.plotting import plot3d_parametric_line
plot3d_parametric_line(cos(x), sin(x), x, (x, -5, 5));
